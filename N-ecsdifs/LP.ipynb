# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import numpy as np
# %matplotlib notebook
import time

# %%
fig=plt.figure()
ax=plt.subplot(111)
plt.grid('on')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
while True:
    x = pd.read_csv(r'C:\Users\Arif\OneDrive - Instituto Tecnologico y de Estudios Superiores de Monterrey\Files\Escuela\Carrera\N-ecsdifs\xs1_matrix.csv').to_numpy()
    y = pd.read_csv(r'C:\Users\Arif\OneDrive - Instituto Tecnologico y de Estudios Superiores de Monterrey\Files\Escuela\Carrera\N-ecsdifs\ys1_matrix.csv').to_numpy()
    z = pd.read_csv(r'C:\Users\Arif\OneDrive - Instituto Tecnologico y de Estudios Superiores de Monterrey\Files\Escuela\Carrera\N-ecsdifs\zs1_matrix.csv').to_numpy()
    plt.plot(x,z)
    #plt.grid('on')
    time.sleep(1)

# %%
plt.cla()
plt.plot(x,y)
# Out:
# [<matplotlib.lines.Line2D at 0x2036b74e400>,
#  <matplotlib.lines.Line2D at 0x2036b74edf0>,
#  <matplotlib.lines.Line2D at 0x2036b74ec70>,
#  <matplotlib.lines.Line2D at 0x2036b74e280>]

# %%
import random
from itertools import count
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

x_vals = []
y_vals = []

index = count()


def animate(i):
    data = pd.read_csv(r'C:\Users\Arif\OneDrive - Instituto Tecnologico y de Estudios Superiores de Monterrey\Files\Escuela\Carrera\N-ecsdifs\data29.csv')
    x = data['Xs']
    y = data['Ys']
    z = data['Zs']

    plt.cla()

    plt.plot(x, y, label='m1')

    plt.legend(loc='upper left')
    plt.tight_layout()

ani = FuncAnimation(plt.gcf(), animate, interval=1000)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Arif\AppData\Local\Temp\ipykernel_18752\1799028035.py:26: UserWarning: frames=None which we can infer the length of, did not pass an explicit *save_count* and passed cache_frame_data=True.  To avoid a possibly unbounded cache, frame data caching has been disabled. To suppress this warning either pass `cache_frame_data=False` or `save_count=MAX_FRAMES`.
#   ani = FuncAnimation(plt.gcf(), animate, interval=1000)

# %%
np.shape(z)
# Out:
# (5000, 4)

# %%
x = pd.read_csv(r'C:\Users\Arif\OneDrive - Instituto Tecnologico y de Estudios Superiores de Monterrey\Files\Escuela\Carrera\N-ecsdifs\xs1_matrix.csv').to_numpy()
y = pd.read_csv(r'C:\Users\Arif\OneDrive - Instituto Tecnologico y de Estudios Superiores de Monterrey\Files\Escuela\Carrera\N-ecsdifs\ys1_matrix.csv').to_numpy()
z = pd.read_csv(r'C:\Users\Arif\OneDrive - Instituto Tecnologico y de Estudios Superiores de Monterrey\Files\Escuela\Carrera\N-ecsdifs\zs1_matrix.csv').to_numpy()

# %%
plt.plot(x,z)
# Out:
# [<matplotlib.lines.Line2D at 0x21a040a2490>,
#  <matplotlib.lines.Line2D at 0x21a040a24f0>,
#  <matplotlib.lines.Line2D at 0x21a040a2520>,
#  <matplotlib.lines.Line2D at 0x21a040a2610>]

# %%
import random
from itertools import count
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

index = count()
#x = pd.read_csv(r'C:\Users\Arif\OneDrive - Instituto Tecnologico y de Estudios Superiores de Monterrey\Files\Escuela\Carrera\N-ecsdifs\xs1_matrix.csv').to_numpy()
#y = pd.read_csv(r'C:\Users\Arif\OneDrive - Instituto Tecnologico y de Estudios Superiores de Monterrey\Files\Escuela\Carrera\N-ecsdifs\ys1_matrix.csv').to_numpy()
#z = pd.read_csv(r'C:\Users\Arif\OneDrive - Instituto Tecnologico y de Estudios Superiores de Monterrey\Files\Escuela\Carrera\N-ecsdifs\zs1_matrix.csv').to_numpy()

def animate(i):
    #data = pd.read_csv(r'C:\Users\Arif\OneDrive - Instituto Tecnologico y de Estudios Superiores de Monterrey\Files\Escuela\Carrera\N-ecsdifs\data29.csv')
    x = pd.read_csv(r'C:\Users\Arif\OneDrive - Instituto Tecnologico y de Estudios Superiores de Monterrey\Files\Escuela\Carrera\N-ecsdifs\xs1_matrix.csv').to_numpy()
    y = pd.read_csv(r'C:\Users\Arif\OneDrive - Instituto Tecnologico y de Estudios Superiores de Monterrey\Files\Escuela\Carrera\N-ecsdifs\ys1_matrix.csv').to_numpy()
    z = pd.read_csv(r'C:\Users\Arif\OneDrive - Instituto Tecnologico y de Estudios Superiores de Monterrey\Files\Escuela\Carrera\N-ecsdifs\zs1_matrix.csv').to_numpy()

    plt.cla()
    plt.subplot(111,projection="3d")
    plt.plot(x, y,z, label='m1')
    plt.show()


    plt.legend(loc='upper left')
    plt.tight_layout()

ani = FuncAnimation(plt.gcf(), animate, interval=180)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Arif\AppData\Local\Temp\ipykernel_18752\3992982988.py:28: UserWarning: frames=None which we can infer the length of, did not pass an explicit *save_count* and passed cache_frame_data=True.  To avoid a possibly unbounded cache, frame data caching has been disabled. To suppress this warning either pass `cache_frame_data=False` or `save_count=MAX_FRAMES`.
#   ani = FuncAnimation(plt.gcf(), animate, interval=180)
# C:\Users\Arif\AppData\Roaming\jupyterlab-desktop\jlab_server\lib\site-packages\matplotlib\animation.py:884: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(

# %%
plt.plot(x,y,z)
# Out:
# [<matplotlib.lines.Line2D at 0x21a7eb70250>,
#  <matplotlib.lines.Line2D at 0x21a001a4730>,
#  <matplotlib.lines.Line2D at 0x21a001ae7c0>,
#  <matplotlib.lines.Line2D at 0x21a001aedc0>]

# %%
# Out:
# array([-2.28114788, -1.62323374,  1.6132234 , -1.77535751])

# %%
import numpy as np
